# %% [markdown]
# TESTING CSV

# %%
from pathlib import Path
import pandas as pd

csv_path = Path.cwd() / "app/assets/Indian_Food_Nutrition_Processed.csv"
test_csv = Path.cwd() / "data/synthetic_health_data.csv"
if not csv_path.exists():
    csv_path = Path.cwd() / "backend/app/assets/Indian_Food_Nutrition_Processed.csv"

df = pd.read_csv(test_csv)

df.head()
# Out:
#   cycle_phase  sleep_hours  stress_level  carbs_g  protein_g  fats_g  \
# 0   menstrual          4.1             3     84.1       14.1    12.7
# 1  follicular          7.6             5    115.5       34.2    25.9
# 2   menstrual          4.5             1    104.6       27.4    24.8
# 3   ovulation          6.9             1     48.2       19.8    26.7
# 4  follicular          7.4             1    149.6       16.1    59.7
#
#    free_sugar_g  fibre_g  sodium_mg  calcium_mg  iron_mg  vitamin_c_mg  \
# 0          51.8     19.5     1812.4        86.6      2.8          34.9
# 1          60.9     26.8      563.0       536.0      7.3          32.3
# 2           3.0     16.6      462.0      1110.6      2.4          44.0
# 3           5.6      8.9      392.9       369.7     16.1          54.7
# 4          11.4     13.9     2969.6       786.0     14.1         102.7
#
#    folate_ug  fatigue_level mood_state  dominant_factor
# 0      369.2              5     groggy        low_sleep
# ...

# %%
# df["Dish Name"]= df["Dish Name"].str.lower()

# df

# new_df = df[df['Dish Name'].str.contains("coffee")]
# df.isnull().sum()
df.dtypes
# Out:
# cycle_phase            str
# sleep_hours        float64
# stress_level         int64
# carbs_g            float64
# protein_g          float64
# fats_g             float64
# free_sugar_g       float64
# fibre_g            float64
# sodium_mg          float64
# calcium_mg         float64
# iron_mg            float64
# vitamin_c_mg       float64
# folate_ug          float64
# fatigue_level        int64
# mood_state             str
# dominant_factor        str
# dtype: object
