# %% [markdown]
# TESTING CSV

# %%
from pathlib import Path
import pandas as pd

csv_path = Path.cwd() / "app/assets/Indian_Food_Nutrition_Processed.csv"
if not csv_path.exists():
    csv_path = Path.cwd() / "backend/app/assets/Indian_Food_Nutrition_Processed.csv"

df = pd.read_csv(csv_path)

# df.head()

# %%
df["Dish Name"]= df["Dish Name"].str.lower()

# df

new_df = df[df['Dish Name'].str.contains("coffee")]
new_df
# Out:
#                       Dish Name  Calories (kcal)  Carbohydrates (g)  \
# 1                instant coffee            23.16               3.65
# 2                espreso coffee            51.54               6.62
# 13   cold coffee with ice cream            67.85              11.24
# 411              coffee biscuit           416.57              46.55
# 434          steeped hot coffee            15.91               3.01
# 436    cold coffee (with cream)            82.76              11.98
# 626            coffee ice cream           150.62              14.09
# 627          coffee pear alaska           203.99              19.36
# 722                coffee drops           443.07              43.06
#
#      Protein (g)  Fats (g)  Free Sugar (g)  Fibre (g)  Sodium (mg)  \
# 1           0.64      0.75            3.62       0.00         4.92
# 2           1.75      2.14            6.53       0.00        13.98
# 13          1.57      2.11           11.18       0.01        13.84
# 411         6.90     23.00           21.69       1.59       112.53
# 434         0.39      0.33            2.96       0.00         2.82
# 436         1.93      3.29           11.91       0.00        15.35
# 626         3.15      9.43           13.35       0.00        42.09
# 627         2.88     13.22           16.88       0.15        51.11
# 722         7.57     27.16           18.27       1.88        88.17
#
#      Calcium (mg)  Iron (mg)  Vitamin C (mg)  Folate (µg)
# 1           20.87       0.06            1.51         5.60
# 2           58.10       0.15            1.51         5.53
# 13          53.29       0.12            2.53         9.49
# 411         48.92       1.27            0.03         3.00
# 434         10.40       0.06            0.30         1.27
# 436         64.43       0.14            2.56         9.52
# 626         95.72       0.15            2.16         7.18
# 627         60.61       0.22            3.48        13.85
# 722         57.09       1.48            0.03         2.72
